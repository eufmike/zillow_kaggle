# %%
import re
import pandas as pd
from pathlib import Path

# %%
def load_df(path, flnames):
    df = []
    for flname in flnames:
        df_tmp = pd.read_csv(path.joinpath(flname), low_memory=False)
        
        # add year
        match = re.match(r'.*([1-3][0-9]{3})', flname)
        if match is not None:
            # Then it found a match!
            year = match.group(1)
            print(year)
        df_tmp['year_data'] = year

        df.append(df_tmp)
    df = pd.concat(df, axis = 0, ignore_index=True)
    return df

data_path = Path("G:\My Drive\Colab Notebooks\Zillow\data")
if (not 'dfall' in locals()) and data_path.joinpath('dfall.pkl').is_file():
    print('load cache')  
    dfall = pd.read_pickle(data_path.joinpath('dfall.pkl')) 
elif (not 'dfall' in locals()) or (not data_path.joinpath('dfall.pkl').is_file()):
    # mix type found without disable low memory mode
    # option: low_memory=False
    properties_flnames = ['properties_2016.csv', 'properties_2017.csv']
    train_flname = ['train_2016_v2.csv', 'train_2017.csv'] 
    df_prop = load_df(data_path, properties_flnames)
    df_trn = load_df(data_path, train_flname)
    dfall = df_prop.merge(df_trn, left_on = ['parcelid', 'year_data'], right_on=['parcelid', 'year_data'], how='outer')
    dfall.to_pickle(data_path.joinpath('dfall.pkl'))
    print('save cache')

display(dfall)
# Out:
# load cache

# %%
dfall.info()

# %%
# fix mix type
# https://medium.com/@dataproducts/pandas-detect-mixed-data-types-and-fix-it-7f0bd3b8d071

for colname in dfall.columns:
    col_tmp = dfall[colname]
    col_tmp_nona = col_tmp[~col_tmp.isna()]
    print(colname)
    print(col_tmp_nona.unique())
# Out:
# parcelid
# [ 10754147  10759547  10843547 ... 168040630 168040830 168040430]
# airconditioningtypeid
# [ 1. 13.  5. 11.  9. 12.  3.]
# architecturalstyletypeid
# [ 7. 21.  8.  2.  3.  5. 10. 27.]
# basementsqft
# [ 216.  555.  224.  782.  651.  516.  600.  732. 1145.  220.  420.  688.
#   144.  540. 1312.  690.  640.  550.   63.  198. 1120.  924. 1572. 1035.
#   195.  544.  498.  176.  360.  154.  240.  616. 1131.  200. 1016. 1089.
#  2443.  276.  396.  149.  168.  495.  208.  560.  939.  704.  460. 1152.
#   462. 1904.  888.  170.  625.  450.   72.  252.  637.   96. 1172. 1464.
#   787.  501.  473.  318.  112.  394.  985.  169.  400.  826.  780. 1350.
#   610. 1528.  255.  164.  315.  836.  630.  160. 1508.  775.  676.  448.
#   756.  912.  179.  700.  348.  595.  231.  100.  266.  620.  757.  786.
#   872.  672.  831. 1544.  946.  180.  313.  314.  440.  528.   36.  320.
#   515.  196.  119. 3374.  606.  736.  678. 1282.  135.   64.  506.  414.
#  1296. 1197. 1112.  814.  530.  165. 1314.  352.  282.  293.  805. 2025.
#   990.  173.  841.  108.  140.  280.  853.  751.  150. 1226.   25.  384.
#  1552.  689.  656.  795. 1560.  899.  864.  234. 1085.  821. 1448.  980.
#   502.  405.  438.  162.  766.  459.  392.  972.  107. 3089.  120. 1040.
#   456. 1932. 1601. 1377.  308. 1483. 1671.  749.   60.  582.  861.  584.
#   250.  357. 1224.  142. 1118.   90.  378. 1369. 2683.  480.  270.  457.
#  '2017-01-17' '2017-02-09' '2017-01-01' '2017-03-27' '2017-02-24'
#  '2017-07-12' '2017-05-30' '2017-05-22' '2017-02-10' '2017-02-16'
#  '2017-04-05' '2017-06-26' '2017-07-18' '2017-05-16' '2017-05-18'
#  '2017-01-25' '2017-03-23' '2017-02-26' '2017-08-22' '2017-05-09'
#  '2017-07-17' '2017-01-05' '2017-01-02' '2017-09-12' '2017-02-20'
#  '2017-09-05' '2017-03-22' '2017-08-29' '2017-02-02' '2017-02-08'
#  '2017-07-21' '2017-02-12' '2017-01-04' '2017-07-24' '2017-08-15'
#  '2017-04-27' '2017-01-16' '2017-02-27' '2017-01-10' '2017-01-20'
#  '2017-06-19' '2017-06-28' '2017-07-20' '2017-07-11' '2017-04-02'
#  '2017-06-05' '2017-01-18' '2017-08-28' '2017-04-17' '2017-03-05'
#  '2017-01-09' '2017-03-03' '2017-01-27' '2017-04-30' '2017-08-02'
#  '2017-08-05' '2017-01-08' '2017-02-25' '2017-07-15' '2017-01-22'
#  '2017-02-05' '2017-06-18' '2017-02-11' '2017-06-25' '2017-09-16'
#  '2017-06-17' '2017-05-29' '2017-04-01' '2017-01-15' '2017-04-16'
#  '2017-03-04' '2017-06-04' '2017-01-21' '2017-07-29' '2017-02-19'
#  '2017-04-29' '2017-08-20' '2017-09-17' '2017-07-01' '2017-01-28'
#  '2017-03-18' '2017-09-02' '2017-06-11' '2017-05-27' '2017-09-20'
#  '2017-07-04' '2017-01-07' '2017-07-16' '2017-02-04' '2017-04-22'
#  '2017-08-26' '2017-07-02' '2017-01-14' '2017-04-09' '2017-07-08'
#  '2017-07-30' '2017-03-19' '2017-03-26' '2017-05-07' '2017-07-23'
#  '2017-06-24' '2017-04-23' '2017-05-28' '2017-05-14' '2017-09-25'
#  '2017-08-12' '2017-08-06' '2017-03-25' '2017-03-11' '2017-02-18'
#  '2017-05-13' '2017-06-03' '2017-09-10' '2017-09-09' '2017-07-09'
#  '2017-09-21' '2017-04-15' '2017-06-10' '2017-03-12' '2017-08-19'
#  '2017-04-08' '2017-08-13' '2017-09-04' '2017-07-22' '2017-05-06'
#  '2017-05-20']

# %%
if (not 'dfall_typemod' in locals()) and data_path.joinpath('dfall_typemod.pkl').is_file():
    print('load cache')
    dfall_typemod = pd.read_pickle(data_path.joinpath('dfall_typemod.pkl')) 
elif (not 'dfall_typemod' in locals()) or (not data_path.joinpath('dfall_typemod.pkl').is_file()):
    # covert year_data to string
    dfall['year_data'] = dfall['year_data'].astype('string')

    # fix object (column with mix types)
    # find column with mix type
    dfall_mixtypeidx = []
    dfall_mixtypecolname = []
    for idx, value in enumerate(dfall.dtypes.items()):
        if value[1] == "object":
            dfall_mixtypeidx.append(idx)
            dfall_mixtypecolname.append(value[1])
    print(f'column idx with mix type: {dfall_mixtypeidx}')

    dfall_mixtypecolname = dfall.columns[dfall_mixtypeidx]
    print(f'column with mix type: {dfall_mixtypecolname}')
    dfall_mixtype = dfall.iloc[:, dfall_mixtypeidx]
    # dfall_mixtype.info()

    # print data types without na
    for mix_idx in dfall_mixtypeidx:
        col = dfall.iloc[:, mix_idx]
        col_nona = col[~col.isna()]
        if isinstance(col_nona.unique()[0], bool):
            print('is bool')
            dfall[dfall.columns[mix_idx]] = dfall[dfall.columns[mix_idx]].fillna(False).astype('bool')
        elif col_nona.unique()[0] == 'Y':
            print('is Y')
            dfall[dfall.columns[mix_idx]] = dfall[dfall.columns[mix_idx]].fillna(False)
            dfall[dfall.columns[mix_idx]] = dfall[dfall.columns[mix_idx]].replace('Y', True)
            dfall[dfall.columns[mix_idx]] = dfall[dfall.columns[mix_idx]].astype('bool')
        elif isinstance(col_nona.unique()[0], str):
            print('is str')
            dfall[dfall.columns[mix_idx]] = dfall[dfall.columns[mix_idx]].fillna('').astype('string')
    dfall.iloc[:, dfall_mixtypeidx].info()
    
    # convert float to int if no decimal
    dfall_floatidx = []
    dfall_floatcolname = []
    for idx, value in enumerate(dfall.dtypes.items()):
        if value[1] == "float64":
            dfall_floatidx.append(idx)
            dfall_floatcolname.append(value[1])
    print(dfall_floatidx)

    def check_num_int(nums):
        status = True
        for num in nums:
            if num % 1 != 0:
                return False
        return status

    for colidx in dfall_floatidx:
        col_unique = pd.Series(dfall.iloc[:, colidx].unique()).dropna()
        #print(col_unique)

        allint_status = check_num_int(col_unique)
        if allint_status:
            dfall[dfall.columns[colidx]] = dfall[dfall.columns[colidx]].astype('Int64')


    # change year to string
    datecols = ['yearbuilt', 'assessmentyear', 'year_data']
    dfall[datecols] = dfall[datecols].astype('Int64') 
    
    # change id and code to string
    stringcol = ['parcelid', 
             'airconditioningtypeid', 
             'architecturalstyletypeid', 
             'buildingclasstypeid', 
             'buildingqualitytypeid', 
             'decktypeid', 
             'fips', 
             'propertylandusetypeid', 
             'regionidzip', 
             'storytypeid', 
             'typeconstructiontypeid', 
             'censustractandblock', 
             ]
    dfall[stringcol] = dfall[stringcol].astype('string') 
    dfall.info()
    dfall.to_pickle(data_path.joinpath('dfall_typemod.pkl'))
    dfall_typemod = dfall.copy()
    print('save cache')
# Out:
# load cache

# %%
dfall_typemod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5970758 entries, 0 to 5970757
# Data columns (total 61 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   parcelid                      string
#  1   airconditioningtypeid         string
#  2   architecturalstyletypeid      string
#  3   basementsqft                  Int64
#  4   bathroomcnt                   float64
#  5   bedroomcnt                    Int64
#  6   buildingclasstypeid           string
#  7   buildingqualitytypeid         string
#  8   calculatedbathnbr             float64
#  9   decktypeid                    string
#  10  finishedfloor1squarefeet      Int64
#  11  calculatedfinishedsquarefeet  Int64
#  12  finishedsquarefeet12          Int64
#  13  finishedsquarefeet13          Int64
#  14  finishedsquarefeet15          Int64
#  15  finishedsquarefeet50          Int64
#  16  finishedsquarefeet6           Int64
#  17  fips                          string
#  18  fireplacecnt                  Int64
#  19  fullbathcnt                   Int64
#  20  garagecarcnt                  Int64
#  21  garagetotalsqft               Int64
#  22  hashottuborspa                bool
#  23  heatingorsystemtypeid         Int64
#  24  latitude                      Int64
#  25  longitude                     Int64
#  26  lotsizesquarefeet             float64
#  27  poolcnt                       Int64
#  28  poolsizesum                   Int64
#  29  pooltypeid10                  Int64
#  30  pooltypeid2                   Int64
#  31  pooltypeid7                   Int64
#  32  propertycountylandusecode     string
#  33  propertylandusetypeid         string
#  34  propertyzoningdesc            string
#  35  rawcensustractandblock        float64
#  36  regionidcity                  Int64
#  37  regionidcounty                Int64
#  38  regionidneighborhood          Int64
#  39  regionidzip                   string
#  40  roomcnt                       Int64
#  41  storytypeid                   string
#  42  threequarterbathnbr           Int64
#  43  typeconstructiontypeid        string
#  44  unitcnt                       Int64
#  45  yardbuildingsqft17            Int64
#  46  yardbuildingsqft26            Int64
#  47  yearbuilt                     Int64
#  48  numberofstories               Int64
#  49  fireplaceflag                 bool
#  50  structuretaxvaluedollarcnt    Int64
#  51  taxvaluedollarcnt             Int64
#  52  assessmentyear                Int64
#  53  landtaxvaluedollarcnt         Int64
#  54  taxamount                     float64
#  55  taxdelinquencyflag            bool
#  56  taxdelinquencyyear            Int64
#  57  censustractandblock           string
#  58  year_data                     Int64
#  59  logerror                      float64
#  60  transactiondate               string
# dtypes: Int64(37), bool(3), float64(6), string(15)
# memory usage: 2.8 GB

# %%
for colname in dfall_typemod.columns:
    col_tmp = dfall_typemod[colname]
    print(colname)
    print(col_tmp.unique())
# Out:
# parcelid
# <StringArray>
# [ '10754147',  '10759547',  '10843547',  '10859147',  '10879947',  '10898347',
#   '10933547',  '10940747',  '10954547',  '10976347',
#  ...
#   '14460030',  '14284830',  '14285230',  '14455630',  '11117630', '168176230',
#   '14273630', '168040630', '168040830', '168040430']
# Length: 2985217, dtype: string
# airconditioningtypeid
# <StringArray>
# [<NA>, '1', '13', '5', '11', '9', '12', '3']
# Length: 8, dtype: string
# architecturalstyletypeid
# <StringArray>
# [<NA>, '7', '21', '8', '2', '3', '5', '10', '27']
# Length: 9, dtype: string
# basementsqft
# <IntegerArray>
# [<NA>,  216,  555,  224,  782,  651,  516,  600,  732, 1145,
#  ...
#  1674,  808, 1071,  996,  557,  806,  393,   77,  284,  136]
# Length: 752, dtype: Int64
# bathroomcnt
# [ 0.    2.    4.    3.    1.    2.5   3.5   5.    1.5   4.5   7.5   5.5
#   6.    7.   10.    8.    9.   12.   11.    8.5   6.5  13.    9.5  14.
#  20.   19.5  15.   10.5    nan 18.   16.    1.75 17.   19.    0.5  12.5
#  11.5  14.5  32.   31.  ]
# bedroomcnt
# <IntegerArray>
# [   0,    4,    5,    2,    3,    1,    6,    7,    8,   12,   11,    9,   10,
#    14,   16,   13, <NA>,   15,   17,   18,   20,   19,   25,   23,   24,   21]
# Length: 26, dtype: Int64
# buildingclasstypeid
# <StringArray>
# [<NA>, '3', '4', '5', '2', '1']
# Length: 6, dtype: string
# buildingqualitytypeid
# <StringArray>
# [<NA>, '7', '4', '10', '1', '12', '8', '3', '6', '9', '5', '11', '2']
# Length: 13, dtype: string
# calculatedbathnbr
# [ nan  2.   4.   3.   1.   2.5  3.5  5.   1.5  4.5  7.5  5.5  6.   7.
#  10.   8.   9.  12.  11.   8.5  6.5 13.   9.5 14.  20.  19.5 15.  10.5
#  18.  16.  17.  19.  12.5 11.5 14.5 32.  31. ]
# decktypeid
# <StringArray>
# [<NA>, '66']
# Length: 2, dtype: string
# finishedfloor1squarefeet
# <IntegerArray>
# [<NA>, 4969, 1080,  780, 1250, 1404, 1193, 1181,  837, 2148,
#  ...
#  3413, 4707,  231,  156,  239, 5745, 4663, 4477, 4550,    1]
# Length: 4641, dtype: Int64
# calculatedfinishedsquarefeet
# <IntegerArray>
# [  <NA>,  73026,   5068,   1776,   2400,   3611,   3754,   2470,   2760,
#    4000,
#  ...
#   21325, 349519,  16375,  26948,  13047, 347123,  11150,  11560, 427079,
#   22300]
# Length: 12724, dtype: Int64
# finishedsquarefeet12
# <IntegerArray>
# [  <NA>,   4000,   3633,   1090,   1620,   2077,   2735,   1200,   9893,
#     171,
#  ...
#    7962,  24804,   9270,  35560,  16838,   9924,  13047,  11560, 427079,
#   22300]
# Length: 10767, dtype: Int64
# finishedsquarefeet13
# <IntegerArray>
# [<NA>, 1440, 1368,  900, 1344,  660, 1248, 1296, 1536, 1464,
#  ...
#  1378, 2016, 1540, 1276,  429,  396, 2304, 1638,  350,  468]
# Length: 251, dtype: Int64
# finishedsquarefeet15
# <IntegerArray>
# [  <NA>,  73026,   5068,   1776,   2400,   3611,   3754,   2470,   2760,
#    4053,
#  ...
#  197762,  22788,  21325, 349519,   9680,  16375,  26948,  10111, 347123,
#   11150]
# Length: 8919, dtype: Int64
# finishedsquarefeet50
# <IntegerArray>
# [ <NA>,  4969,  1080,   780,  1250,  1404,  1193,  1181,   837,  2148,
#  ...
#  11659,  4915, 12467,  3964,  4477,  8461,  8307, 11780, 11235,  7234]
# Length: 4903, dtype: Int64
# finishedsquarefeet6
# <IntegerArray>
# [ <NA>, 15341,  1863,  1084,  2100,   996,  2876,  3905,  1939,  2340,
#  ...
#   5471,  3046,  2973,  2339,  3888,  1303,   364,  4522, 13200,  3282]
# Length: 4254, dtype: Int64
# fips
# <StringArray>
# ['6037', '6059', '6111', <NA>]
# Length: 4, dtype: string
# fireplacecnt
# <IntegerArray>
# [<NA>, 3, 1, 2, 4, 9, 5, 7, 6, 8]
# Length: 10, dtype: Int64
# fullbathcnt
# <IntegerArray>
# [<NA>,    2,    4,    3,    1,    5,    7,    6,   10,    8,    9,   12,   11,
#    13,   14,   20,   19,   15,   18,   16,   17,   32,   31]
# Length: 23, dtype: Int64
# garagecarcnt
# <IntegerArray>
# [<NA>,    2,    4,    1,    3,    0,    5,    7,    6,    8,    9,   12,   11,
#    10,   13,   14,   15,   25,   21,   18,   17,   24,   19,   16,   20]
# Length: 25, dtype: Int64
# garagetotalsqft
# <IntegerArray>
# [<NA>,  420,  525,  428,  522,  440,    0,  507, 1022,  619,
#  ...
#  1613, 3589, 1809, 1953, 2148, 2888, 3144, 2180, 3048, 3018]
# Length: 2260, dtype: Int64
# hashottuborspa
# [False  True]
# heatingorsystemtypeid
# <IntegerArray>
# [<NA>, 2, 7, 20, 6, 13, 18, 24, 12, 10, 1, 14, 21, 11, 19]
# Length: 15, dtype: Int64
# latitude
# <IntegerArray>
# [34144442, 34140430, 33989359, 34148863, 34194168, 34171873, 34131929,
#  34171345, 34218210, 34289776,
#  ...
#  34480002, 34660869, 33671332, 33740025, 34509669, 34607693, 33668077,
#  33690560, 33686479, 33464849]
# Length: 852840, dtype: Int64
# longitude
# <IntegerArray>
# [-118654084, -118625364, -118394633, -118437206, -118385816, -118380906,
#  -118351474, -118314900, -118331311, -118432085,
#  ...
#  -117686252, -117754612, -117730901, -118883936, -118585513, -119034406,
#  -118237183, -119287061, -117751841, -118235543]
# Length: 1043471, dtype: Int64
# lotsizesquarefeet
# [ 85768.   4083.  63085. ...  39139. 735176.  61729.]
# poolcnt
# <IntegerArray>
# [<NA>, 1]
# Length: 2, dtype: Int64
# poolsizesum
# <IntegerArray>
# [<NA>,  800,  450,  503,  735,  903,  400,   70,  648,  645,
#  ...
#   970,  928,  892, 1032,  197,   30, 1566,  821, 6000,  176]
# Length: 908, dtype: Int64
# pooltypeid10
# <IntegerArray>
# [<NA>, 1]
# Length: 2, dtype: Int64
# pooltypeid2
# <IntegerArray>
# [<NA>, 1]
# Length: 2, dtype: Int64
# pooltypeid7
# <IntegerArray>
# [<NA>, 1]
# Length: 2, dtype: Int64
# propertycountylandusecode
# <StringArray>
# ['010D', '0109', '1200', '1210', '010V', '300V', '0100', '0200', '010C',
#  '0300',
#  ...
#  '0308', '7100', '121X', '0231', '03TO', '030B', '01MC', '12T4', '5011',
#  '3414']
# Length: 241, dtype: string
# propertylandusetypeid
# <StringArray>
# ['269', '261',  '47',  '31', '260', '266', '246', '247', '248', '263', '265',
#  '275', '267', '264', '270',  <NA>, '279']
# Length: 17, dtype: string
# propertyzoningdesc
# <StringArray>
# [          '',     'LCA11*',       'LAC2',       'LAM1',       'LAC4',
#      'BUC4YY',      'BUR1*',      'SFC2*',      'SCUR3',     'LCA25*',
#  ...
#    'LCMX-DRU',      'LAR-1',       'LRMU',       'BFM1',   'GLDSP/TD',
#      'SPM1AY', 'GDR3_GRAND',  'LCRAGOOO*',    'LARI-I*',       'PDCP']
# Length: 5665, dtype: string
# rawcensustractandblock
# [60378002.041    60378001.011002 60377030.012017 ... 60371251.002
#  60376703.281008 60375728.001015]
# regionidcity
# <IntegerArray>
# [ 37688,  51617,  12447, 396054,  47547,   <NA>,  54311,  40227,   5534,
#   45888,
#  ...
#   27512,   6285,  24797,  40633,  48211,   3980,  37882,  47913,  36078,
#   19202]
# Length: 187, dtype: Int64
# regionidcounty
# <IntegerArray>
# [3101, 1286, 2061, <NA>]
# Length: 4, dtype: Int64
# regionidneighborhood
# <IntegerArray>
# [  <NA>,  27080,  46795, 274049,  31817,  37739, 115729,   7877, 762191,
#   13327,
#  ...
#  761217, 275316, 411726, 764092, 764091, 275287, 764146, 274108, 273552,
#  273622]
# Length: 530, dtype: Int64
# regionidzip
# <StringArray>
# ['96337', '96095', '96424', '96450', '96446', '96049', '96434', '96436',
#  '96366', '96370',
#  ...
#  '96068', '96114', '97185', '96034', '96069', '96258', '96953', '96313',
#  '97096', '96453']
# Length: 406, dtype: string
# roomcnt
# <IntegerArray>
# [   0,    8,    4,    5,    7,    6,   11,    3,   10,    9,    2,   12,   86,
#    13,   15,   18,   22,   14,    1,   19, <NA>,   21,   30,   16,   67,   56,
#    42,   17,   24,   84,   20,   31,   77,   40,   52,   96,   45]
# Length: 37, dtype: Int64
# storytypeid
# <StringArray>
# [<NA>, '7']
# Length: 2, dtype: string
# threequarterbathnbr
# <IntegerArray>
# [<NA>, 1, 2, 4, 3, 6, 5, 7]
# Length: 8, dtype: Int64
# typeconstructiontypeid
# <StringArray>
# [<NA>, '6', '4', '10', '13', '11']
# Length: 6, dtype: string
# unitcnt
# <IntegerArray>
# [<NA>,    2,    1,    3,    5,    4,    9,   48,   13,   22,
#  ...
#   217,  116,   99,  340,  416,   82,  478,  106,  122,  299]
# Length: 157, dtype: Int64
# yardbuildingsqft17
# <IntegerArray>
# [<NA>,  450,   94,  240,  466,  627,  210,  868,  132,  528,
#  ...
#  1912, 1713, 1794, 1007, 1390, 1507, 3086, 1876, 3191, 1283]
# Length: 1668, dtype: Int64
# yardbuildingsqft26
# <IntegerArray>
# [<NA>, 1280,  140,  560,  240,  253,   26,  160,  135,  170,
#  ...
#   295, 2400,  430,  646,  588,  708,  779, 1005,  944,  371]
# Length: 595, dtype: Int64
# yearbuilt
# <IntegerArray>
# [<NA>, 1948, 1947, 1943, 1946, 1978, 1958, 1949, 1956, 2005,
#  ...
#  1842, 1860, 1826, 1872, 1802, 1820, 1852, 1847, 1866, 1861]
# Length: 184, dtype: Int64
# numberofstories
# <IntegerArray>
# [<NA>, 1, 4, 2, 3, 41, 5, 6, 20, 7, 14, 17, 8]
# Length: 13, dtype: Int64
# fireplaceflag
# [False  True]
# structuretaxvaluedollarcnt
# <IntegerArray>
# [  <NA>, 650756, 571346, 193796, 176383, 397945, 101998, 218440, 245834,
#   32654,
#  ...
#  647407, 377003, 730519, 592768, 722511, 416191, 509172, 470775, 331885,
#  388642]
# Length: 570438, dtype: Int64
# taxvaluedollarcnt
# <IntegerArray>
# [      9,   27516, 1413387, 1156834,  433491,  283315,  554573,  688486,
#   261201,  430208,
#  ...
#   846280,  830808,  641757,  960756,  798647,  653311, 1455497,  477419,
#   653611,  594022]
# Length: 901309, dtype: Int64
# assessmentyear
# <IntegerArray>
# [2015, 2014, 2003, 2012, 2001, 2011, 2013, 2016, 2010, <NA>, 2004, 2005, 2002,
#  2000, 2009]
# Length: 15, dtype: Int64
# landtaxvaluedollarcnt
# <IntegerArray>
# [      9,   27516,  762631,  585488,  239695,  106932,  156628,  586488,
#    42761,  184374,
#  ...
#   789500, 1312515,  620604,  849510, 2191890,  557621,  612455,  749091,
#   644231, 1299596]
# Length: 736137, dtype: Int64
# taxamount
# [     nan 20800.37 14557.57 ... 35053.92 19313.08 13494.52]
# taxdelinquencyflag
# [False  True]
# taxdelinquencyyear
# <IntegerArray>
# [<NA>,   13,   15,   11,   14,    9,   10,    8,   12,    7,    6,    2,   92,
#     5,    3,    4,   95,   91,   93,   98,   82,   79,   94,   97,   90,   99,
#     0,    1,   87,   84,   86,   88,   96]
# Length: 33, dtype: Int64
# censustractandblock
# <StringArray>
# [            <NA>, '61110010011023', '61110009032019', '61110010024015',
#  '61110010023002', '61110010024021', '61110010021029', '61110010022038',
#  '61110010022029', '61110010022009',
#  ...
#  '61110052041019', '60375440011020', '60374019022013', '60371319002010',
#  '61110011021034', '61110057001043', '60830017062032', '61110059091005',
#  '60590423381001', '61110057001029']
# Length: 96793, dtype: string
# year_data
# <IntegerArray>
# [2016, 2017]
# Length: 2, dtype: Int64
# logerror
# [        nan  0.0953      0.0198     ... -0.01660037  0.10807295
#   0.08271221]
# transactiondate
# <StringArray>
# [          '', '2016-01-27', '2016-03-30', '2016-05-27', '2016-06-07',
#  '2016-08-08', '2016-08-26', '2016-07-08', '2016-05-11', '2016-06-15',
#  ...
#  '2017-04-15', '2017-06-10', '2017-03-12', '2017-08-19', '2017-04-08',
#  '2017-08-13', '2017-09-04', '2017-07-22', '2017-05-06', '2017-05-20']
# Length: 617, dtype: string

# %%
if (not 'dfall_fillna' in locals()) and data_path.joinpath('dfall_fillna.pkl').is_file():
    print('load cache')
    dfall_fillna = pd.read_pickle(data_path.joinpath('dfall_fillna.pkl')) 
elif (not 'dfall_fillna' in locals()) or (not data_path.joinpath('dfall_fillna.pkl').is_file()):
    fillnadict = {
        'string': {'fillvale': 'NA', 'new_type': 'string'},
        'int64': {'fillvale': -1, 'new_type': 'int64'},
        'Int64': {'fillvale': -1, 'new_type': 'int64'},
        'float64': {'fillvale': 0, 'new_type': 'float64'},
    }

    excludecol = ['logerror']

    def fillnabytypes(df, fillnadict):
        df_new = df.copy()
        for key, value in fillnadict.items():
            coltypeidx = []
            coltypenms = []
            for idx, value in enumerate(df_new.dtypes.items()):
                if str(value[1]) == key:
                    coltypeidx.append(idx)
                    coltypenms.append(value[0])
            for coltypenm in coltypenms:
                nact = sum(df[coltypenm].isna())
                print(f'na ct:{nact}')
                if nact > 0 and (not coltypenm in excludecol): 
                    print('fill na')
                    df_new[coltypenm] = df_new[coltypenm].fillna(fillnadict[key]['fillvale'])
                    print(f'na ct:{sum(df_new[coltypenm].isna())}')
                df_new[coltypenm] = df_new[coltypenm].astype(fillnadict[key]['new_type'])
                print(f'change colname : {coltypenm} type: {key}, fillna: {fillnadict[key]}')
        return df_new
    
    dfall_fillna = fillnabytypes(dfall_typemod, fillnadict)
    dfall_fillna.to_pickle(data_path.joinpath('dfall_fillna.pkl'))
# Out:
# na ct:0
# change colname : parcelid type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:4343790
# fill na
# na ct:0
# change colname : airconditioningtypeid type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:5958634
# fill na
# na ct:0
# change colname : architecturalstyletypeid type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:5945398
# fill na
# na ct:0
# change colname : buildingclasstypeid type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:2090658
# fill na
# na ct:0
# change colname : buildingqualitytypeid type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:5936283
# fill na
# na ct:0
# change colname : decktypeid type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:14370
# fill na
# na ct:0
# change colname : fips type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:0
# change colname : propertycountylandusecode type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:14370
# fill na
# na ct:0
# change colname : propertylandusetypeid type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:0
# change colname : propertyzoningdesc type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:26695
# fill na
# na ct:0
# change colname : regionidzip type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:5967511
# fill na
# na ct:0
# change colname : storytypeid type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:5957263
# fill na
# na ct:0
# change colname : typeconstructiontypeid type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:150117
# fill na
# na ct:0
# change colname : censustractandblock type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:0
# change colname : transactiondate type: string, fillna: {'fillvale': 'NA', 'new_type': 'string'}
# na ct:5967503
# fill na
# na ct:0
# change colname : basementsqft type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:14396
# fill na
# na ct:0
# change colname : bedroomcnt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5564263
# fill na
# na ct:0
# change colname : finishedfloor1squarefeet type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:100671
# fill na
# na ct:0
# change colname : calculatedfinishedsquarefeet type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:540503
# fill na
# na ct:0
# change colname : finishedsquarefeet12 type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5955414
# fill na
# na ct:0
# change colname : finishedsquarefeet13 type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5589748
# fill na
# na ct:0
# change colname : finishedsquarefeet15 type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5564263
# fill na
# na ct:0
# change colname : finishedsquarefeet50 type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5927273
# fill na
# na ct:0
# change colname : finishedsquarefeet6 type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5344974
# fill na
# na ct:0
# change colname : fireplacecnt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:246082
# fill na
# na ct:0
# change colname : fullbathcnt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:4196397
# fill na
# na ct:0
# change colname : garagecarcnt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:4196397
# fill na
# na ct:0
# change colname : garagetotalsqft type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:2294987
# fill na
# na ct:0
# change colname : heatingorsystemtypeid type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:14370
# fill na
# na ct:0
# change colname : latitude type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:14370
# fill na
# na ct:0
# change colname : longitude type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:4913530
# fill na
# na ct:0
# change colname : poolcnt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5914835
# fill na
# na ct:0
# change colname : poolsizesum type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5916810
# fill na
# na ct:0
# change colname : pooltypeid10 type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5905627
# fill na
# na ct:0
# change colname : pooltypeid2 type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:4979342
# fill na
# na ct:0
# change colname : pooltypeid7 type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:124977
# fill na
# na ct:0
# change colname : regionidcity type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:14370
# fill na
# na ct:0
# change colname : regionidcounty type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:3657475
# fill na
# na ct:0
# change colname : regionidneighborhood type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:14445
# fill na
# na ct:0
# change colname : roomcnt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5342747
# fill na
# na ct:0
# change colname : threequarterbathnbr type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:2012004
# fill na
# na ct:0
# change colname : unitcnt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5808809
# fill na
# na ct:0
# change colname : yardbuildingsqft17 type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5965465
# fill na
# na ct:0
# change colname : yardbuildingsqft26 type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:107772
# fill na
# na ct:0
# change colname : yearbuilt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:4602944
# fill na
# na ct:0
# change colname : numberofstories type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:101452
# fill na
# na ct:0
# change colname : structuretaxvaluedollarcnt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:76817
# fill na
# na ct:0
# change colname : taxvaluedollarcnt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:14373
# fill na
# na ct:0
# change colname : assessmentyear type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:127660
# fill na
# na ct:0
# change colname : landtaxvaluedollarcnt type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:5857755
# fill na
# na ct:0
# change colname : taxdelinquencyyear type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:0
# change colname : year_data type: Int64, fillna: {'fillvale': -1, 'new_type': 'int64'}
# na ct:14420
# fill na
# na ct:0
# change colname : bathroomcnt type: float64, fillna: {'fillvale': 0, 'new_type': 'float64'}
# na ct:246082
# fill na
# na ct:0
# change colname : calculatedbathnbr type: float64, fillna: {'fillvale': 0, 'new_type': 'float64'}
# na ct:548839
# fill na
# na ct:0
# change colname : lotsizesquarefeet type: float64, fillna: {'fillvale': 0, 'new_type': 'float64'}
# na ct:14370
# fill na
# na ct:0
# change colname : rawcensustractandblock type: float64, fillna: {'fillvale': 0, 'new_type': 'float64'}
# na ct:54003
# fill na
# na ct:0
# change colname : taxamount type: float64, fillna: {'fillvale': 0, 'new_type': 'float64'}
# na ct:5802870
# change colname : logerror type: float64, fillna: {'fillvale': 0, 'new_type': 'float64'}

# %%
if (not 'dfall_logerr' in locals()) and data_path.joinpath('dfall_logerr.pkl').is_file():
    print('load cache')
    dfall_logerr = pd.read_pickle(data_path.joinpath('dfall_logerr.pkl')) 
elif (not 'dfall_logerr' in locals()) or (not data_path.joinpath('dfall_logerr.pkl').is_file()):
    dfall_logerr = dfall_fillna[~dfall_fillna['logerror'].isna()]
    dfall_logerr.to_pickle(data_path.joinpath('dfall_logerr.pkl'))

# %%
dfall_logerr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167888 entries, 362 to 5970723
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   parcelid                      167888 non-null  string
#  1   airconditioningtypeid         167888 non-null  string
#  2   architecturalstyletypeid      167888 non-null  string
#  3   basementsqft                  167888 non-null  int64
#  4   bathroomcnt                   167888 non-null  float64
#  5   bedroomcnt                    167888 non-null  int64
#  6   buildingclasstypeid           167888 non-null  string
#  7   buildingqualitytypeid         167888 non-null  string
#  8   calculatedbathnbr             167888 non-null  float64
#  9   decktypeid                    167888 non-null  string
#  10  finishedfloor1squarefeet      167888 non-null  int64
#  11  calculatedfinishedsquarefeet  167888 non-null  int64
#  12  finishedsquarefeet12          167888 non-null  int64
#  13  finishedsquarefeet13          167888 non-null  int64
#  14  finishedsquarefeet15          167888 non-null  int64
#  15  finishedsquarefeet50          167888 non-null  int64
#  16  finishedsquarefeet6           167888 non-null  int64
#  17  fips                          167888 non-null  string
#  18  fireplacecnt                  167888 non-null  int64
#  19  fullbathcnt                   167888 non-null  int64
#  20  garagecarcnt                  167888 non-null  int64
#  21  garagetotalsqft               167888 non-null  int64
#  22  hashottuborspa                167888 non-null  bool
#  23  heatingorsystemtypeid         167888 non-null  int64
#  24  latitude                      167888 non-null  int64
#  25  longitude                     167888 non-null  int64
#  26  lotsizesquarefeet             167888 non-null  float64
#  27  poolcnt                       167888 non-null  int64
#  28  poolsizesum                   167888 non-null  int64
#  29  pooltypeid10                  167888 non-null  int64
#  30  pooltypeid2                   167888 non-null  int64
#  31  pooltypeid7                   167888 non-null  int64
#  32  propertycountylandusecode     167888 non-null  string
#  33  propertylandusetypeid         167888 non-null  string
#  34  propertyzoningdesc            167888 non-null  string
#  35  rawcensustractandblock        167888 non-null  float64
#  36  regionidcity                  167888 non-null  int64
#  37  regionidcounty                167888 non-null  int64
#  38  regionidneighborhood          167888 non-null  int64
#  39  regionidzip                   167888 non-null  string
#  40  roomcnt                       167888 non-null  int64
#  41  storytypeid                   167888 non-null  string
#  42  threequarterbathnbr           167888 non-null  int64
#  43  typeconstructiontypeid        167888 non-null  string
#  44  unitcnt                       167888 non-null  int64
#  45  yardbuildingsqft17            167888 non-null  int64
#  46  yardbuildingsqft26            167888 non-null  int64
#  47  yearbuilt                     167888 non-null  int64
#  48  numberofstories               167888 non-null  int64
#  49  fireplaceflag                 167888 non-null  bool
#  50  structuretaxvaluedollarcnt    167888 non-null  int64
#  51  taxvaluedollarcnt             167888 non-null  int64
#  52  assessmentyear                167888 non-null  int64
#  53  landtaxvaluedollarcnt         167888 non-null  int64
#  54  taxamount                     167888 non-null  float64
#  55  taxdelinquencyflag            167888 non-null  bool
#  56  taxdelinquencyyear            167888 non-null  int64
#  57  censustractandblock           167888 non-null  string
#  58  year_data                     167888 non-null  int64
#  59  logerror                      167888 non-null  float64
#  60  transactiondate               167888 non-null  string
# dtypes: bool(3), float64(6), int64(37), string(15)
# memory usage: 76.1 MB

# %%
for colname in dfall_logerr.columns:
    col_tmp = dfall_logerr[colname]
    print(colname)
    print(col_tmp.unique())
# Out:
# parcelid
# <StringArray>
# ['17073783', '17088994', '17100444', '17102429', '17109604', '17125829',
#  '17132911', '17134926', '17139988', '17167359',
#  ...
#  '11924390', '12139606', '12136406', '13008207', '12006414', '11928618',
#  '10813418', '11934023', '11490025', '11864428']
# Length: 165210, dtype: string
# airconditioningtypeid
# <StringArray>
# ['NA', '1', '5', '13', '11', '9', '3']
# Length: 7, dtype: string
# architecturalstyletypeid
# <StringArray>
# ['NA', '7', '21', '8', '2', '3', '10']
# Length: 7, dtype: string
# basementsqft
# [  -1  616 1350  676  831 1528  234  485  814  760  196  690  238  802
#   168  330 1551 1312  260  184  579  700  585  493 1048  540  100  515
#   510  198  771  564  162  608  312  913 1555  671 1210  557  394  314
#  1252  396  674  819  912  204  800 1416  384   90  640  380  254  600
#  1809  645  786  669  512  273  300  900  200  224 1969   38  604  405
#   112 3112  352 1218  588  280  252 3560  126]
# bathroomcnt
# [ 2.5  1.   2.   1.5  3.   7.   5.   0.   4.   4.5  3.5  5.5  6.  10.
#   8.   9.   6.5 12.  11.   7.5  8.5 20.  15.  18.  13. ]
# bedroomcnt
# [ 3  2  4  5  6  1  0  8 10  7 12  9 13 11 15 16 14 -1]
# buildingclasstypeid
# <StringArray>
# ['NA', '4', '3']
# Length: 3, dtype: string
# buildingqualitytypeid
# <StringArray>
# ['NA', '4', '7', '10', '1', '8', '12', '6', '11', '9', '3', '5', '2']
# Length: 13, dtype: string
# calculatedbathnbr
# [ 2.5  1.   2.   1.5  3.   7.   5.   0.   4.   4.5  3.5  5.5  6.  10.
#   8.   9.   6.5 12.  11.   7.5  8.5 20.  15.  18.  13. ]
# decktypeid
# <StringArray>
# ['NA', '66']
# Length: 2, dtype: string
# finishedfloor1squarefeet
# [ 548  777 1101 ... 3396 4079 1966]
# calculatedfinishedsquarefeet
# [1264  777 1101 ... 4798 6895 6435]
# finishedsquarefeet12
# [1264  777 1101 ... 4798 6895 6435]
# finishedsquarefeet13
# [  -1 1440 1416 1344 1536 1584 1056 1566 1248 1464 1152 1392 1488 1300
#  1512 1200 1560 1060]
# finishedsquarefeet15
# [  -1 1700 2114 ... 1294 3616 3079]
# finishedsquarefeet50
# [ 548  777 1101 ... 3396 4079 1966]
# finishedsquarefeet6
#   728  931  257  616 1065  427  969  499 1120  832  598  507  306  582
#   661  604  990  850  327  799  738  673  773  238  635  362   38  694
#   663  474 1200   65  712  552  794  414  574  515]
# pooltypeid10
# [-1  1]
# pooltypeid2
# [-1  1]
# pooltypeid7
# [-1  1]
# propertycountylandusecode
# <StringArray>
# ['1128', '1129', '1111', '1110', '010C', '0100', '0101', '010D', '010E',
#  '0200', '0700', '0400', '0300',  '122',   '34', '01DC',    '1', '012C',
#  '01HC', '100V', '1117', '0104', '020G', '0109',   '96', '1321', '010V',
#  '1222', '1116', '010M', '1210', '010G', '0103',   '38', '010H',   '73',
#  '1112', '0108',  '135', '010F', '1014', '1410', '012D', '0201', '6050',
#  '070D', '1200', '0401', '1720', '020M',  '105', '012E', '1012', '1011',
#  '1310',  '010', '040V', '030G', '0110', '0102', '1421', '1432', '0303',
#  '0111', '0130', '1333', '01DD',    '0', '0210', '0131', '8800', '040A',
#   '200', '0301', '1722', '1420',     '', '0114', '0113', '0203', '0141',
#  '01HE', '020E', '0105', '040G', '0204', '010L', '0133', '1120', '040B',
#  '0115']
# Length: 91, dtype: string
# propertylandusetypeid
# <StringArray>
# ['265', '266', '261', '269', '246', '263', '248', '247', '275', '260', '267',
#  '264',  '31',  '47',  'NA']
# Length: 15, dtype: string
# propertyzoningdesc
# <StringArray>
# [          '',      'LARD3',       'LARS',     'LARE11',     'LCA21*',
#        'LAR1',    'LARD1.5',      'LARD2',       'LAR3',     'LARE15',
#  ...
#   'BFA15000*',   'DOR17500',       'LKR*',     'LCR1-*', 'CSCR-SC-RM',
#       'PDC3*',      'SGC3*', 'AHRS-(3)10',   'POR4-R2*',   'WCRIAD1*']
# Length: 2347, dtype: string
# rawcensustractandblock
# [61110022.003007 61110015.031002 61110007.011007 ... 60379100.021083
#  60590218.152           0.      ]
# regionidcity
# [ 34543  26965  51239  13150  25974  34278  27110  53655  12447     -1
#  396054  47547  54311  10734  40227  29189  25621   5534  16677  45888
#   45398 113412  51617  55753  33612  19177  26964  10389  37688  12520
#  396550  50677  33837  14111  48424  45457  47019  50749  46080  30187
#  396053  24174  47762   4406   6395  30399  17882  25953  26483  10774
#   12292  46298  10723 118878   3491  54722  54053  33727   5465  53636
#  118225 396556  39306  18875  24384  30908  20008  33836  24245  14542
#   32923  10241  24435  37015  11626  39308 118217  24812  16764  42967
#   53571  24832  34780   8384  25218  54352  44833  17150  21412  26531
#   40081  27491  47568  38032  52650  32380  25458  37086  25459  17686
#   13693  17597  15554  12773  46098  33840  41673  52835  33252  51861
#   13091  47198   9840  46178  54212   6021  54299 114834  47695 118994
#   27103  53027  13716  14634  45602  22827 118895  34636  18874  10608
#   46314  42150  27183 396551 118914  32616 118694  40009  25271  44116
#   39076  33311   6822  15237  52842  38980  29712 116042  32753  30267
#   33312  16389  18098  40110  25468  16961  56780  21778  36502 272578
#  114828  31134 113576  13232 118880  21395  54970  24797  42091  14906
#   10815 118875  32927  34037  53162  13311  37882   6285  36078]
# regionidcounty
# [2061 3101 1286   -1]
# regionidneighborhood
# [    -1  48570 268588  40548  27987  47950  51906  41466  32368  27080
# [-1 15 13 14 11  9 12 10  8  7  6 99  4  3]
# censustractandblock
# <StringArray>
# ['61110022003007', '61110015031002', '61110007011007', '61110008002013',
#  '61110014021007', '61110052022034', '61110055032010', '61110055041004',
#  '61110053041014', '61110039002008',
#  ...
#  '60590994154012', '60590992292016', '60590740044003', '60590629002036',
#  '60590992431012', '60371132321009', '60590755154146', '60375427003021',
#  '60379100021083', '60379010042010']
# Length: 57545, dtype: string
# year_data
# [2016 2017]
# logerror
# [ 0.0953      0.0198      0.006      ... -0.01660037  0.10807295
#   0.08271221]
# transactiondate
# <StringArray>
# ['2016-01-27', '2016-03-30', '2016-05-27', '2016-06-07', '2016-08-08',
#  '2016-08-26', '2016-07-08', '2016-05-11', '2016-06-15', '2016-10-07',
#  ...
#  '2017-04-15', '2017-06-10', '2017-03-12', '2017-08-19', '2017-04-08',
#  '2017-08-13', '2017-09-04', '2017-07-22', '2017-05-06', '2017-05-20']
# Length: 616, dtype: string

# %%
dfall_fillna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5970758 entries, 0 to 5970757
# Data columns (total 61 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   parcelid                      string
#  1   airconditioningtypeid         string
#  2   architecturalstyletypeid      string
#  3   basementsqft                  UInt64
#  4   bathroomcnt                   float64
#  5   bedroomcnt                    int64
#  6   buildingclasstypeid           string
#  7   buildingqualitytypeid         string
#  8   calculatedbathnbr             float64
#  9   decktypeid                    string
#  10  finishedfloor1squarefeet      int64
#  11  calculatedfinishedsquarefeet  int64
#  12  finishedsquarefeet12          int64
#  13  finishedsquarefeet13          int64
#  14  finishedsquarefeet15          int64
#  15  finishedsquarefeet50          int64
#  16  finishedsquarefeet6           int64
#  17  fips                          string
#  18  fireplacecnt                  int64
#  19  fullbathcnt                   int64
#  20  garagecarcnt                  int64
#  21  garagetotalsqft               int64
#  22  hashottuborspa                bool
#  23  heatingorsystemtypeid         int64
#  24  latitude                      int64
#  25  longitude                     int64
#  26  lotsizesquarefeet             float64
#  27  poolcnt                       int64
#  28  poolsizesum                   int64
#  29  pooltypeid10                  int64
#  30  pooltypeid2                   int64
#  31  pooltypeid7                   int64
#  32  propertycountylandusecode     string
#  33  propertylandusetypeid         string
#  34  propertyzoningdesc            string
#  35  rawcensustractandblock        float64
#  36  regionidcity                  int64
#  37  regionidcounty                int64
#  38  regionidneighborhood          int64
#  39  regionidzip                   string
#  40  roomcnt                       int64
#  41  storytypeid                   string
#  42  threequarterbathnbr           int64
#  43  typeconstructiontypeid        string
#  44  unitcnt                       int64
#  45  yardbuildingsqft17            int64
#  46  yardbuildingsqft26            int64
#  47  yearbuilt                     int64
#  48  numberofstories               int64
#  49  fireplaceflag                 bool
#  50  structuretaxvaluedollarcnt    int64
#  51  taxvaluedollarcnt             int64
#  52  assessmentyear                int64
#  53  landtaxvaluedollarcnt         int64
#  54  taxamount                     float64
#  55  taxdelinquencyflag            bool
#  56  taxdelinquencyyear            int64
#  57  censustractandblock           string
#  58  year_data                     int64
#  59  logerror                      float64
#  60  transactiondate               string
# dtypes: UInt64(1), bool(3), float64(6), int64(36), string(15)
# memory usage: 2.6 GB
